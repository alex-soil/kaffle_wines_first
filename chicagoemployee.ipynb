# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/chicagoemployers/chicago.csv

# %%
import pandas as pd
import numpy as np
import polars as ps

# %%
df = pd.read_csv('/kaggle/input/chicagoemployers/chicago.csv').dropna(how ="all")
#[column_name.replace(" ","_") for column_name in df.columns]

# %%
#df.info()
df["Department"].nunique()
df.nunique()
df["Department"] = df["Department"].astype("category")

# %%
df["Name"] = df["Name"].str.lower().str.title()
df["Department"] = df["Department"].str.title()
df["Position Title"] = df["Position Title"].str.title()

# %%
"hello world".replace("l", "!")
# Out:
# 'he!!o wor!d'

# %%
df["Department"]= df["Department"]\
                    .str.replace("Mgmnt", "Management")

# %%
df["Employee Annual Salary"] = df["Employee Annual Salary"].str.replace("$","").astype(float)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.

# %%
mask = df["Position Title"].str.contains("Water")
mask1 = df["Position Title"].str.startswith("Water")
mask2=df["Position Title"].str.endswith("ist")
df[mask2]
# Out:
#                           Name                        Position Title  \
# 184             Afroz,  Nayyar                          Psychiatrist
# 308           Alarcon,  Luis J            Loan Processing Specialist
# 422           Allain,  Carolyn  Senior Telecommunications Specialist
# 472             Allen,  Robert                             Machinist
# 705        Anderson,  Edward M             Sr Procurement Specialist
# ...                        ...                                   ...
# 31667         Yoder,  Teresa G                   Archival Specialist
# 31688  Youngbloom,  Laurence G        Crimes Surveillance Specialist
# 31717       Young,  Kimberly M             Sr Procurement Specialist
# 31837            Zapata,  Hugo             Sr Procurement Specialist
# 31918        Zemke,  Richard P                             Machinist
#
#                   Department  Employee Annual Salary
# 184                   Health                 99840.0
# ...

# %%
"    Hello  ".strip()
# Out:
# 'Hello'

# %%
'Hello my name'.split(" ")
# Out:
# ['Hello', 'my', 'name']

# %%
#Separating lasn name and first name and assign it to new column
#df["Last Name"] = df["Name"].str.split(",").str.get(0)
df.head(3)
# Out:
#                 Name    Position Title        Department  \
# 0    Aaron,  Elvia J  Water Rate Taker  Water Management
# 1  Aaron,  Jeffery M    Police Officer            Police
# 2     Aaron,  Karina    Police Officer            Police
#
#    Employee Annual Salary
# 0                 90744.0
# 1                 84450.0
# 2                 84450.0

# %%
df["Name"].str.split(",").str.get(1).str.strip().str.split(" ")\
          .str.get(0).value_counts().head(3)
# Out:
# Michael    1153
# John        899
# James       676
# Name: Name, dtype: int64

# %%
#Split name and surname, added to the right side of df
df[["LastName", "FirstName"]] = df["Name"].str.split(",", expand = True)

# %%
#Split only by first space
df['Position Title'].str.split(" ", expand = True, n=1)
# Out:
#             0                           1
# 0       Water                  Rate Taker
# 1      Police                     Officer
# 2      Police                     Officer
# 3       Chief          Contract Expediter
# 4       Civil                 Engineer Iv
# ...       ...                         ...
# 32057     Frm  Of Machinists - Automotive
# 32058  Police                     Officer
# 32059  Police                     Officer
# 32060  Police                     Officer
# 32061   Chief           Data Base Analyst
#
# [32062 rows x 2 columns]
