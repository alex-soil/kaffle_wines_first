# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
nba=pd.read_csv("nba.csv")

# %%
nba.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
nba[nba.Salary.isna()]
# Out:
#                Name                    Team  Number Position   Age Height  \
# 2      John Holland          Boston Celtics    30.0       SG  27.0    6-5
# 46      Elton Brand      Philadelphia 76ers    42.0       PF  37.0    6-9
# 171   Dahntay Jones     Cleveland Cavaliers    30.0       SG  35.0    6-6
# 264   Jordan Farmar       Memphis Grizzlies     4.0       PG  29.0    6-2
# 269    Ray McCallum       Memphis Grizzlies     5.0       PG  24.0    6-3
# 270  Xavier Munford       Memphis Grizzlies    14.0       PG  24.0    6-3
# 273  Alex Stepheson       Memphis Grizzlies    35.0       PF  28.0   6-10
# 350   Briante Weber              Miami Heat    12.0       PG  23.0    6-2
# 353   Dorell Wright              Miami Heat    11.0       SF  30.0    6-9
# 397    Axel Toupane          Denver Nuggets     6.0       SG  23.0    6-7
# 409      Greg Smith  Minnesota Timberwolves     4.0       PF  25.0   6-10
# 456     Jeff Withey                      Ut     NaN      NaN   NaN    NaN
#
#      Weight                College  Salary
# 2     205.0      Boston University     NaN
# 46    254.0                   Duke     NaN
# 171   225.0                   Duke     NaN
# 264   180.0                   UCLA     NaN
# 269   190.0                Detroit     NaN
# 270   180.0           Rhode Island     NaN
# 273   270.0                    USC     NaN
# 350   165.0  Virginia Commonwealth     NaN
# 353   205.0                    NaN     NaN
# 397   210.0                    NaN     NaN
# 409   250.0           Fresno State     NaN
# 456     NaN                    NaN     NaN

# %%
nba = nba.fillna({"Salary": 0})

# %%
nba["Salary"] = nba["Salary"].astype("int")

# %%
nba.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary        int32
# dtype: object

# %%
nba.groupby("Team", as_index=False).agg({"Salary": "sum"})\
    .sort_values("Salary", ascending = False)
# Out:
#                       Team     Salary
# 5      Cleveland Cavaliers  106988689
# 12    Los Angeles Clippers   94854640
# 20   Oklahoma City Thunder   93765298
# 9    Golden State Warriors   88868997
# 4            Chicago Bulls   86783378
# 26       San Antonio Spurs   84442733
# 18    New Orleans Pelicans   82750774
# 15              Miami Heat   82515673
# 3        Charlotte Hornets   78340920
# 14       Memphis Grizzlies   76550880
# 30      Washington Wizards   76328636
# 10         Houston Rockets   75283021
# 19         New York Knicks   73303898
# 0            Atlanta Hawks   72902950
# 13      Los Angeles Lakers   71770431
# 25        Sacramento Kings   71683666
# 6         Dallas Mavericks   71198732
# 27         Toronto Raptors   71117611
# 16         Milwaukee Bucks   69603517
# 8          Detroit Pistons   67168263
# 11          Indiana Pacers   66751826
# 23            Phoenix Suns   63445135
# 29               Utah Jazz   62112815
# 21           Orlando Magic   60161470
# 7           Denver Nuggets   60121930
# 17  Minnesota Timberwolves   59709697
# 1           Boston Celtics   58541068
# 2            Brooklyn Nets   52528475
# 24  Portland Trail Blazers   48301818
# 22      Philadelphia 76ers   30992894
# 28                      Ut          0

# %%
cleveland = nba.query("Team == 'Cleveland Cavaliers'")
